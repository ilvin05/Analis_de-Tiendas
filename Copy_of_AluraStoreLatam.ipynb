# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import geopandas as gpd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
# Total Vendido de la Primera tienda
tienda['Precio'].sum()
# Out:
# np.float64(1150880400.0)

# %%
# Total Vendido de la Segunda tienda
tienda2['Precio'].sum()
# Out:
# np.float64(1116343500.0)

# %%
# Total Vendido de la Tercera tienda
tienda3['Precio'].sum()
# Out:
# np.float64(1098019600.0)

# %%
# Total Vendido de la Cuarta tienda
tienda4['Precio'].sum()
# Out:
# np.float64(1038375700.0)

# %%
# Aqui tenemos el valor total vendido entre todas las tiendas
venta_total = tienda['Precio'].sum() + tienda2['Precio'].sum() + tienda3['Precio'].sum() + tienda4['Precio'].sum()
print(venta_total)
# Out:
# 4403619200.0

# %% [markdown]
# # 2. Ventas por categoría

# %%
#Aqui agrupamos las categorias y les asignamos el valor vendido por categoria
# Ala tienda1
tienda.groupby('Categoría del Producto')['Precio'].sum()
# Out:
# Categoría del Producto
# Artículos para el hogar     12698400.0
# Deportes y diversión        39290000.0
# Electrodomésticos          363685200.0
# Electrónicos               429493500.0
# Instrumentos musicales      91299000.0
# Juguetes                    17995700.0
# Libros                       8784900.0
# Muebles                    187633700.0
# Name: Precio, dtype: float64

# %%
#Aqui agrupamos las categorias y les asignamos el valor vendido por categoria
# Ala tienda2
tienda2.groupby('Categoría del Producto')['Precio'].sum()
# Out:
# Categoría del Producto
# Artículos para el hogar     14746900.0
# Deportes y diversión        34744500.0
# Electrodomésticos          348567800.0
# Electrónicos               410831100.0
# Instrumentos musicales     104990300.0
# Juguetes                    15945400.0
# Libros                      10091200.0
# Muebles                    176426300.0
# Name: Precio, dtype: float64

# %%
#Aqui agrupamos las categorias y les asignamos el valor vendido por categoria
# Ala tienda1
tienda3.groupby('Categoría del Producto')['Precio'].sum()
# Out:
# Categoría del Producto
# Artículos para el hogar     15060000.0
# Deportes y diversión        35593100.0
# Electrodomésticos          329237900.0
# Electrónicos               410775800.0
# Instrumentos musicales      77380900.0
# Juguetes                    19401100.0
# Libros                       9498700.0
# Muebles                    201072100.0
# Name: Precio, dtype: float64

# %%
#Aqui agrupamos las categorias y les asignamos el valor vendido por categoria
# Ala tienda1
tienda4.groupby('Categoría del Producto')['Precio'].sum()
# Out:
# Categoría del Producto
# Artículos para el hogar     15074500.0
# Deportes y diversión        33350100.0
# Electrodomésticos          283260200.0
# Electrónicos               409476100.0
# Instrumentos musicales      75102400.0
# Juguetes                    20262200.0
# Libros                       9321300.0
# Muebles                    192528900.0
# Name: Precio, dtype: float64

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificacios_tienda1 = tienda.groupby('Producto')['Calificación'].mean()
# Visualizamos las calificaciones promedio de la tienda_1
calificacios_tienda1
# Out:
# Producto
# Ajedrez de madera              4.428571
# Armario                        3.950000
# Asistente virtual              4.075000
# Auriculares                    3.640000
# Auriculares con micrófono      3.969697
# Balón de baloncesto            3.872727
# Balón de voleibol              4.071429
# Batería                        4.188679
# Bicicleta                      3.944444
# Bloques de construcción        4.089286
# Cama box                       4.113636
# Cama king                      3.772727
# Carrito de control remoto      4.134615
# Celular ABXY                   3.818182
# Ciencia de datos con Python    4.102564
# Cubertería                     4.230769
# Cubo mágico 8x8                4.068182
# Cuerda para saltar             3.625000
# Dashboards con Power BI        3.952381
# Dinosaurio Rex                 3.775000
# Estufa                         4.133333
# Guitarra acústica              3.956522
# Guitarra eléctrica             4.085106
# ...

# %%
calificacios_tienda2 = tienda2.groupby('Producto')['Calificación'].mean()
# Visualizamos las calificaciones promedio de la tienda_2
calificacios_tienda2
# Out:
# Producto
# Ajedrez de madera              4.111111
# Armario                        3.888889
# Asistente virtual              3.842105
# Auriculares                    3.837838
# Auriculares con micrófono      3.886364
# Balón de baloncesto            4.095238
# Balón de voleibol              3.826087
# Batería                        4.032787
# Bicicleta                      4.533333
# Bloques de construcción        4.277778
# Cama box                       4.085106
# Cama king                      4.444444
# Carrito de control remoto      4.127660
# Celular ABXY                   4.048780
# Ciencia de datos con Python    3.837209
# Cubertería                     3.615385
# Cubo mágico 8x8                3.622222
# Cuerda para saltar             4.040000
# Dashboards con Power BI        4.000000
# Dinosaurio Rex                 4.333333
# Estufa                         4.000000
# Guitarra acústica              4.000000
# Guitarra eléctrica             3.893617
# ...

# %%
calificacios_tienda3 = tienda3.groupby('Producto')['Calificación'].mean()
# Visualizamos las calificaciones promedio de la tienda_3
calificacios_tienda3
# Out:
# Producto
# Ajedrez de madera              3.851064
# Armario                        4.142857
# Asistente virtual              3.692308
# Auriculares                    4.023256
# Auriculares con micrófono      3.794872
# Balón de baloncesto            4.000000
# Balón de voleibol              3.729167
# Batería                        3.975610
# Bicicleta                      3.769231
# Bloques de construcción        4.342857
# Cama box                       3.869565
# Cama king                      4.035714
# Carrito de control remoto      4.192308
# Celular ABXY                   4.363636
# Ciencia de datos con Python    4.021739
# Cubertería                     3.871795
# Cubo mágico 8x8                4.181818
# Cuerda para saltar             3.905660
# Dashboards con Power BI        4.350000
# Dinosaurio Rex                 4.086957
# Estufa                         4.226415
# Guitarra acústica              3.936170
# Guitarra eléctrica             4.078947
# ...

# %%
calificacios_tienda4 = tienda4.groupby('Producto')['Calificación'].mean()
# Visualizamos las calificaciones promedio de la tienda_4
calificacios_tienda4
# Out:
# Producto
# Ajedrez de madera              4.000000
# Armario                        4.235294
# Asistente virtual              4.040000
# Auriculares                    4.318182
# Auriculares con micrófono      3.976190
# Balón de baloncesto            3.880000
# Balón de voleibol              4.291667
# Batería                        4.333333
# Bicicleta                      3.888889
# Bloques de construcción        3.814815
# Cama box                       3.983871
# Cama king                      3.857143
# Carrito de control remoto      3.945455
# Celular ABXY                   3.897436
# Ciencia de datos con Python    3.842105
# Cubertería                     3.983051
# Cubo mágico 8x8                3.851064
# Cuerda para saltar             4.279070
# Dashboards con Power BI        4.017857
# Dinosaurio Rex                 4.000000
# Estufa                         3.829787
# Guitarra acústica              3.675676
# Guitarra eléctrica             3.787879
# ...

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# ####Productos mas vendidos en la tienda Alura Store_1

# %%
# Productos Mas Vendidos Tienda_1
productos_mas_vendidos = tienda.groupby('Producto')['Precio'].sum()
# Visualizamos el top 10 de los producto Mas vendido de la tienda_1
productos_mas_vendidos.nlargest(10)
# Out:
# Producto
# TV LED UHD 4K         142150200.0
# Refrigerador          112143300.0
# Iphone 15              97902200.0
# Smart TV               67452100.0
# Lavadora de ropa       65783600.0
# Lavavajillas           62054900.0
# Secadora de ropa       59062400.0
# Tablet ABXY            47639800.0
# Batería                37693900.0
# Guitarra eléctrica     37292200.0
# Name: Precio, dtype: float64

# %% [markdown]
# ####Productos menos vendidos en la tienda Alura Store_1

# %%
# Productos Menos Vendidos Tienda_1
productos_menos_vendidos = tienda.groupby('Producto')['Precio'].sum()
# Visualizamos el top 10 de los producto Menos vendido de la tienda_1
productos_mas_vendidos.nsmallest(10)
# Out:
# Producto
# Cuerda para saltar              652800.0
# Dinosaurio Rex                  688900.0
# Cubo mágico 8x8                 696900.0
# Set de vasos                   1359100.0
# Ajedrez de madera              1430600.0
# Dashboards con Power BI        1455700.0
# Bloques de construcción        1865700.0
# Muñeca bebé                    1937300.0
# Ciencia de datos con Python    2063600.0
# Iniciando en programación      2093100.0
# Name: Precio, dtype: float64

# %% [markdown]
# ####Productos mas vendidos en la tienda Alura Store_2

# %%
productos_mas_vendidos_2 = tienda2.groupby('Producto')['Precio'].sum()
# Visualizamos el top 10 de los producto Mas vendido de la tienda_2
productos_mas_vendidos_2.nlargest(10)
# Out:
# Producto
# Iphone 15           113225800.0
# TV LED UHD 4K       103375000.0
# Refrigerador         97632500.0
# Lavadora de ropa     66762300.0
# Smart TV             61142000.0
# Secadora de ropa     59115100.0
# Lavavajillas         58767500.0
# Tablet ABXY          56209800.0
# Batería              46175300.0
# Celular ABXY         41668900.0
# Name: Precio, dtype: float64

# %% [markdown]
# ####Productos menos vendidos en la tienda Alura Store_2

# %%
productos_menos_vendidos_2 = tienda2.groupby('Producto')['Precio'].sum()
# Visualizamos el top 10 de los producto Menos vendido de la tienda_2
productos_menos_vendidos_2.nsmallest(10)
# Out:
# Producto
# Cubo mágico 8x8             643600.0
# Dinosaurio Rex              770300.0
# Cuerda para saltar          856900.0
# Ajedrez de madera          1287700.0
# Set de vasos               1542600.0
# Dashboards con Power BI    1599500.0
# Cubertería                 1732900.0
# Bloques de construcción    1789400.0
# Balón de baloncesto        2091300.0
# Vaso térmico               2155900.0
# Name: Precio, dtype: float64

# %% [markdown]
# ####Productos mas vendidos en la tienda Alura Store_3

# %%
productos_mas_vendidos_3 = tienda3.groupby('Producto')['Precio'].sum()
# Visualizamos el top 10 de los producto Mas vendido de la tienda_3
productos_mas_vendidos_3.nlargest(10)
# Out:
# Producto
# Refrigerador        99889700.0
# TV LED UHD 4K       96669100.0
# Iphone 15           93225700.0
# Smart TV            78837300.0
# Lavavajillas        64364800.0
# Tablet ABXY         58440100.0
# Lavadora de ropa    57459100.0
# Secadora de ropa    49798300.0
# Celular ABXY        43419600.0
# Cama king           38834700.0
# Name: Precio, dtype: float64

# %% [markdown]
# ####Productos menos vendidos en la tienda Alura Store_3

# %%
productos_menos_vendidos_3 = tienda3.groupby('Producto')['Precio'].sum()
# Visualizamos el top 10 de los producto Menos vendido de la tienda_3
productos_menos_vendidos_3.nsmallest(10)
# Out:
# Producto
# Cubo mágico 8x8             640400.0
# Dinosaurio Rex              795600.0
# Cuerda para saltar          853800.0
# Set de vasos               1210700.0
# Bloques de construcción    1237200.0
# Ajedrez de madera          1355300.0
# Dashboards con Power BI    1372600.0
# Vaso térmico               1725600.0
# Cubertería                 1775900.0
# Muñeca bebé                1932600.0
# Name: Precio, dtype: float64

# %% [markdown]
# ####Productos mas vendidos en la tienda Alura Store_4

# %%
productos_mas_vendidos_4 = tienda4.groupby('Producto')['Precio'].sum()
# Visualizamos el top 10 de los producto Mas vendido de la tienda_4
productos_mas_vendidos_4.nlargest(10)

# %% [markdown]
# ####Productos menos vendidos en la tienda Alura Store_4

# %%
productos_menos_vendidos_4 = tienda4.groupby('Producto')['Precio'].sum()
# Visualizamos el top 10 de los producto Menos vendido de la tienda_4
productos_menos_vendidos_4.nsmallest(10)
# Out:
# Producto
# Cuerda para saltar              704800.0
# Cubo mágico 8x8                 748400.0
# Dinosaurio Rex                  858100.0
# Ajedrez de madera              1075500.0
# Set de vasos                   1471800.0
# Bloques de construcción        1909800.0
# Dashboards con Power BI        1990600.0
# Ciencia de datos con Python    2108800.0
# Iniciando en programación      2118200.0
# Vaso térmico                   2152500.0
# Name: Precio, dtype: float64

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
costo_de_envio_tienda1 = tienda.groupby('Producto')['Costo de envío'].mean()
costo_de_envio_tienda1
# Out:
# Producto
# Ajedrez de madera                1691.836735
# Armario                         26068.333333
# Asistente virtual               10620.000000
# Auriculares                      5694.000000
# Auriculares con micrófono        8221.212121
# Balón de baloncesto              2560.000000
# Balón de voleibol                2440.476190
# Batería                         37956.603774
# Bicicleta                       26827.777778
# Bloques de construcción          1644.642857
# Cama box                        26277.272727
# Cama king                       37884.090909
# Carrito de control remoto        3655.769231
# Celular ABXY                    52954.545455
# Ciencia de datos con Python      2705.128205
# Cubertería                       2051.923077
# Cubo mágico 8x8                   911.363636
# Cuerda para saltar               2065.000000
# Dashboards con Power BI          2040.476190
# Dinosaurio Rex                   1740.000000
# Estufa                          35204.444444
# ...

# %%
costo_de_envio_tienda2 = tienda2.groupby('Producto')['Costo de envío'].mean()
costo_de_envio_tienda2
# Out:
# Producto
# Ajedrez de madera                1735.555556
# Armario                         25912.962963
# Asistente virtual               10886.842105
# Auriculares                      4413.513514
# Auriculares con micrófono        6250.000000
# Balón de baloncesto              2885.714286
# Balón de voleibol                2847.826087
# Batería                         40404.918033
# Bicicleta                       27002.222222
# Bloques de construcción          1840.740741
# Cama box                        27591.489362
# Cama king                       32837.777778
# Carrito de control remoto        4165.957447
# Celular ABXY                    54068.292683
# Ciencia de datos con Python      2969.767442
# Cubertería                       2051.282051
# Cubo mágico 8x8                  1582.222222
# Cuerda para saltar               1478.000000
# Dashboards con Power BI          2030.232558
# Dinosaurio Rex                    995.238095
# Estufa                          38130.952381
# ...

# %%
costo_de_envio_tienda3 = tienda3.groupby('Producto')['Costo de envío'].mean()
costo_de_envio_tienda3

# %%
costo_de_envio_tienda4 = tienda4.groupby('Producto')['Costo de envío'].mean()
costo_de_envio_tienda4

# %%
tienda4['Costo de envío'].mean()
# Out:
# np.float64(23459.457167090754)

# %% [markdown]
# # 6. Vizualizacion

# %% [markdown]
# ###Porcentaje de venta por tienda

# %%
valores = [
    tienda['Precio'].sum(),
    tienda2['Precio'].sum(),
    tienda3['Precio'].sum(),
    tienda4['Precio'].sum(),

]
fig, ax = plt.subplots()
etiquetas = ['Alura Store Brazil', 'Alura Store EEUU', 'Alura Store RD', 'Alura Store Haiti']
colors =['#89AFAE','#7CA2A0','#618985','#51675D']
plt.pie(valores,colors=colors, labels=etiquetas, autopct='%1.1f%%')
plt.title('Porcentaje de Ventas por Tienda')
plt.show()

# %% [markdown]
# ##Ventas por categorias y tiendas

# %% [markdown]
# ### Porsentaje de ventas en la Tienda **Alura Brazicil**.

# %%
x =tienda['Categoría del Producto']
y = tienda['Precio']
plt.title('Ventas por Categoría de Producto tienda Alura Brazil')
plt.xlabel('Ventas')
plt.ylabel('Categoría del Producto')
plt.barh (x, y,color = ['#89AFAE'] )
plt.show()

# %% [markdown]
# ### Ventas por categoria en la tienda **Alura EEUU**

# %%
x =tienda2['Categoría del Producto']
y = tienda['Precio']
plt.title('Ventas por Categoría de Producto tienda Alura EEUU')
plt.xlabel('Ventas')
plt.ylabel('Categoría del Producto')
plt.barh(x, y,color = ['#89AFAE'])
plt.show()

# %% [markdown]
# ###Venta por categoria en la Tienda **Alura RD**

# %%
fig, ax = plt.subplots()
x =tienda3['Categoría del Producto']
y = tienda['Precio']
plt.title('Ventas por Categoría de Producto en la tienda Alura RD')
plt.xlabel('Ventas')
plt.ylabel('Categoría del Producto')
plt.barh(x, y,color = ['#89AFAE'])
plt.show()

# %% [markdown]
# ###Ventas por categoria en la tienda **Alura Haiti**

# %%
fig, ax = plt.subplots()
ax.barh(tienda4['Categoría del Producto'], tienda4['Precio'],color = ['#89AFAE'])
plt.title('Ventas por Categoría de Producto en la tienda Alura Haiti')
plt.xlabel('Ventas')
plt.ylabel('Categoría del Producto')
plt.show()

# %% [markdown]
# #

# %%
tienda.columns
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %% [markdown]
# # Top 3 de los mejores Vendedores por tienda

# %% [markdown]
# ### Alura store Brazil top 3 de los mejores vendedores

# %%
mejores_vendedores = tienda['Vendedor'].value_counts().nlargest(3)
fig, ax = plt.subplots()
color = '#7CA2A0'
ax.bar( mejores_vendedores.index,mejores_vendedores.values, color = ['#7CA2A0','#618985','#51675D'])
plt.title('Top 3 de los mejores Vendedores en Alura Brazil')
plt.xlabel('Vendedor')
plt.ylabel('Ventas')
plt.show()

# %% [markdown]
# ### Top 3 de los mejores vendedores de Alura Store EEUU

# %%
mejores_vendedores = tienda2['Vendedor'].value_counts().nlargest(3)
fig, ax = plt.subplots()
ax.bar(mejores_vendedores.index, mejores_vendedores.values,color = ['#7CA2A0','#618985','#51675D'])
plt.title('Top 3 de los mejores Vendedores en Alura EEUU')
plt.xlabel('Vendedor')
plt.ylabel('Ventas')
plt.show()

# %% [markdown]
# ### Top 3 de los mejores Vendedores de Aulura Store RD

# %%
mejores_vendedores = tienda3['Vendedor'].value_counts().nlargest(3)
fig, ax = plt.subplots()
ax.bar(mejores_vendedores.index, mejores_vendedores.values,color = ['#7CA2A0','#618985','#51675D'])
plt.title('Top 3 de los mejores Vendedores en Alura RD')
plt.xlabel('Vendedor')
plt.ylabel('Ventas')
plt.show()

# %% [markdown]
# Top 3 de los mejores vendedores Alura store Haiti

# %%
mejores_vendedores = tienda4['Vendedor'].value_counts().nlargest(3)
fig, ax = plt.subplots()
ax.bar(mejores_vendedores.index, mejores_vendedores.values, color = ['#7CA2A0','#618985','#51675D'])
plt.title('Top 3 de los mejores Vendedores en Alura Haiti')
plt.xlabel('Vendedor')
plt.ylabel('Ventas')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 5))
valores = [
    tienda['Precio'].sum(),
    tienda2['Precio'].sum(),
    tienda3['Precio'].sum(),
    tienda4['Precio'].sum(),

]
etiquetas = ['Alura Brazil', 'Alura EEUU', 'Alura RD', 'Alura Haiti']
ax.bar(etiquetas, valores, color = ['#7CA2A0','#7CA2A0','#618985','#51675D'])
plt.title(' Ventas por Tienda')
plt.xlabel('Tiendas')
plt.ylabel('Ventas')
plt.show()

# %% [markdown]
# ###Costos de envio por tienda

# %%
valores = [
    tienda['Costo de envío'].mean(),
    tienda2['Costo de envío'].mean(),
    tienda3['Costo de envío'].mean(),
    tienda4['Costo de envío'].mean(),
]
fig, ax = plt.subplots()
color ='#7CA2A0'
etiquetas = ['Alura Brazil', 'Alura EEUU', 'Alura RD', 'Alura Haiti']
plt.plot(etiquetas, valores,color)
plt.title('Costos de Envío por Tienda')
plt.show()

# %% [markdown]
# # Informe de Análisis de Rendimiento de Tiendas
#
# ####Realizado por: Ilvin
# ####Destinatario: Señor Juan

# %% [markdown]
# ###Introducción
#
# Señor Juan,
# Con el propósito de ayudarle a identificar cuál de sus tiendas es la opción más conveniente para vender, realicé un análisis detallado de las ventas, las categorías de productos, las calificaciones de los clientes y los costes de envío de cada una de ellas.
# Este informe presenta los resultados obtenidos y, con base en ellos, expongo mi recomendación final, explicando de manera clara las razones que respaldan la decisión.
#
# ###Resumen General del Análisis
#
# Luego de revisar cuidadosamente los datos de cada tienda, pude observar lo siguiente:
#
# Las Tiendas 1 y 2 generan la mayor parte de los ingresos.
#
# La Tienda 4 es la que menos facturación presenta.
#
# Las calificaciones promedio de los productos son similares en todas las tiendas (alrededor de 4.0/5).
#
# El coste de envío más bajo también pertenece a la Tienda 4, aunque no compensa su menor volumen de ventas.
#
# Después de analizar estos puntos en conjunto, considero que la tienda que más le conviene vender es la Tienda 4. A continuación, explico los detalles que justifican esta conclusión.
#
# ###Desarrollo del Análisis
# **Ingresos Totales**
#
# Los ingresos de cada tienda son:
#
# Tienda 1: 1,150,880,400.0
#
# Tienda 2: 1,116,343,500.0
#
# Tienda 3: 1,098,019,600.0
#
# Tienda 4: 1,038,375,700.0
#
# El total general es de 4,403,619,200.0.
#
# Al ver estos números, observé que la Tienda 4 es la que menor aporte hace al total, representando aproximadamente 23.6 % del volumen de ventas, mientras que la Tienda 1 alcanza más del 26 %.
#
# ###Categorías Más y Menos Vendidas
#
# En las cuatro tiendas noté un patrón muy claro:
#
# La categoría Electrónicos es la más fuerte en todas.
#
# Las categorías de menor venta suelen ser Libros, Juguetes y Artículos para el Hogar.
#
# Esto me indica que su negocio se fortalece principalmente en productos de electrónica y electrodomésticos, mientras que las demás categorías funcionan como complementos.
#
# ###Calificaciones de los Clientes
#
# Revisé las calificaciones de los productos y encontré que:
#
# El promedio general ronda los 4.0 sobre 5, lo cual es bastante positivo.
#
# No existe una diferencia marcada entre tiendas, por lo que este punto no influye significativamente en la decisión de vender una u otra.
#
# Esto confirma que los clientes están satisfechos en general y que no hay una tienda con problemas notorios de reputación.
#
# ###Productos Más Vendidos
#
# Los productos con mayor facturación incluyen:
#
# TV LED UHD 4K
#
# Refrigeradores
#
# iPhone 15
#
# Smart TV
#
# Lavadoras, secadoras y lavavajillas
#
# Casi todos pertenecen al sector de Electrónicos y Electrodomésticos, reafirmando que estas categorías son la columna vertebral del negocio.
#
# Coste de Envío Promedio
#
# El análisis del coste de envío mostró lo siguiente:
#
# Tienda 1: 26,018.61
#
# Tienda 2: 25,216.24
#
# Tienda 3: 24,805.68
#
# Tienda 4: 23,459.46
#
# Aunque la Tienda 4 tiene el coste de envío más bajo, su diferencia de ahorro no compensa su menor nivel de ventas.
#
# ###Conclusión y Recomendación Personal
#
# Después de analizar cada indicador con detenimiento, considero que la tienda que debería vender es la Tienda 4.
# Mi decisión se basa en las siguientes razones:
#
# Es la tienda con menor facturación, contribuyendo menos al total general.
#
# En todas las categorías, especialmente Electrónicos, queda por debajo de la Tienda 3.
#
# Aunque posea un coste de envío más bajo, esta ventaja no equilibra la pérdida en ingresos.
#
# No presenta un área destacada que indique un potencial de crecimiento superior al de las demás.
#
# Por todo esto, vender la Tienda 4 permitiría concentrar recursos, esfuerzos y estrategias en las otras tres tiendas que muestran mejores resultados y mayor potencial de expansión.
